# %%
dbutils.widgets.text("Environment", "dev", "Set the current environment/catalog name")
env = dbutils.widgets.get("Environment")

# %%
# %run "./02_setup"

# %%
SH = SetupHelper(env)
SH.cleanup()

# %%
dbutils.notebook.run("./07_run", 600, {"Environment": env, "RunType": "once"})

# %%
# %run "./03_history_loader"

# %%
HL = HistoryLoader(env)
SH.validate()
HL.validate()

# %%
# %run "./08_producer"

# %%
producer = Producer()
producer.produce(1)
#dbutils.notebook.run("./07_run", 600, {"Environment": env, "RunType": "once"})

# %%
producer = Producer()
producer.produce(2)
dbutils.notebook.run("./07_run", 600, {"Environment": env, "RunType": "once"})
